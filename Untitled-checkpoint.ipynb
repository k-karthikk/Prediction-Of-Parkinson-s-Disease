# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Parkinsson disease.csv')

# %% [raw]
# MDVP:Fo(Hz) - Average vocal fundamental frequency
# MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
# MDVP:Flo(Hz) - Minimum vocal fundamental frequency
# MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
# measures of variation in fundamental frequency
# MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
# NHR,HNR - Two measures of ratio of noise to tonal components in the voice
# status - Health status of the subject (one) - Parkinson's, (zero) - healthy
# RPDE,D2 - Two nonlinear dynamical complexity measures
# DFA - Signal fractal scaling exponent
# spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
df
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0    phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1    phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2    phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3    phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4    phon_R01_S01_5      116.014       141.781       110.655         0.01284
# ..              ...          ...           ...           ...             ...
# 190  phon_R01_S50_2      174.188       230.978        94.261         0.00459
# 191  phon_R01_S50_3      209.516       253.017        89.488         0.00564
# 192  phon_R01_S50_4      174.688       240.005        74.287         0.01360
# 193  phon_R01_S50_5      198.764       396.961        74.904         0.00740
# 194  phon_R01_S50_6      214.289       260.277        77.973         0.00567
#
# ...

# %%
df.dtypes
# Out:
# name                 object
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# name                0
# MDVP:Fo(Hz)         0
# MDVP:Fhi(Hz)        0
# MDVP:Flo(Hz)        0
# MDVP:Jitter(%)      0
# MDVP:Jitter(Abs)    0
# MDVP:RAP            0
# MDVP:PPQ            0
# Jitter:DDP          0
# MDVP:Shimmer        0
# MDVP:Shimmer(dB)    0
# Shimmer:APQ3        0
# Shimmer:APQ5        0
# MDVP:APQ            0
# Shimmer:DDA         0
# NHR                 0
# HNR                 0
# status              0
# RPDE                0
# DFA                 0
# spread1             0
# spread2             0
# D2                  0
# PPE                 0
# dtype: int64

# %%
df['name'].unique()
# Out:
# array(['phon_R01_S01_1', 'phon_R01_S01_2', 'phon_R01_S01_3',
#        'phon_R01_S01_4', 'phon_R01_S01_5', 'phon_R01_S01_6',
#        'phon_R01_S02_1', 'phon_R01_S02_2', 'phon_R01_S02_3',
#        'phon_R01_S02_4', 'phon_R01_S02_5', 'phon_R01_S02_6',
#        'phon_R01_S04_1', 'phon_R01_S04_2', 'phon_R01_S04_3',
#        'phon_R01_S04_4', 'phon_R01_S04_5', 'phon_R01_S04_6',
#        'phon_R01_S05_1', 'phon_R01_S05_2', 'phon_R01_S05_3',
#        'phon_R01_S05_4', 'phon_R01_S05_5', 'phon_R01_S05_6',
#        'phon_R01_S06_1', 'phon_R01_S06_2', 'phon_R01_S06_3',
#        'phon_R01_S06_4', 'phon_R01_S06_5', 'phon_R01_S06_6',
#        'phon_R01_S07_1', 'phon_R01_S07_2', 'phon_R01_S07_3',
#        'phon_R01_S07_4', 'phon_R01_S07_5', 'phon_R01_S07_6',
#        'phon_R01_S08_1', 'phon_R01_S08_2', 'phon_R01_S08_3',
#        'phon_R01_S08_4', 'phon_R01_S08_5', 'phon_R01_S08_6',
#        'phon_R01_S10_1', 'phon_R01_S10_2', 'phon_R01_S10_3',
# ...

# %%
df.drop('name',1,inplace = True)
df
# Out:
# C:\Users\SANTHO~1\AppData\Local\Temp/ipykernel_8112/1393132962.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   df.drop('name',1,inplace = True)
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
# ...

# %%
df.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Fhi(Hz)        float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:RAP            float64
# MDVP:PPQ            float64
# Jitter:DDP          float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
cols=['MDVP:RAP','Jitter:DDP','MDVP:Fhi(Hz)']

# %%
X=df.drop(cols,axis=1)

# %%
X.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:PPQ            float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# status                int64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
X
# Out:
#      MDVP:Fo(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:PPQ  \
# 0        119.992        74.997         0.00784           0.00007   0.00554
# 1        122.400       113.819         0.00968           0.00008   0.00696
# 2        116.682       111.555         0.01050           0.00009   0.00781
# 3        116.676       111.366         0.00997           0.00009   0.00698
# 4        116.014       110.655         0.01284           0.00011   0.00908
# ..           ...           ...             ...               ...       ...
# 190      174.188        94.261         0.00459           0.00003   0.00259
# 191      209.516        89.488         0.00564           0.00003   0.00292
# 192      174.688        74.287         0.01360           0.00008   0.00564
# 193      198.764        74.904         0.00740           0.00004   0.00390
# 194      214.289        77.973         0.00567           0.00003   0.00317
#
# ...

# %%
ss = pd.DataFrame(X)

ss.to_csv (r'C:/Users/SanthoshkumarSambamo/Downloads/parkinsons/final.csv', index = False, header=True)

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
#y = df["status"]

# %%
#df.drop('status',1,inplace = True)
#df

# %%
df
# Out:
#      MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0        119.992       157.302        74.997         0.00784
# 1        122.400       148.650       113.819         0.00968
# 2        116.682       131.111       111.555         0.01050
# 3        116.676       137.871       111.366         0.00997
# 4        116.014       141.781       110.655         0.01284
# ..           ...           ...           ...             ...
# 190      174.188       230.978        94.261         0.00459
# 191      209.516       253.017        89.488         0.00564
# 192      174.688       240.005        74.287         0.01360
# 193      198.764       396.961        74.904         0.00740
# 194      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374
# 1             0.00008   0.00465   0.00696     0.01394       0.06134
# ...

# %%
df['status'].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
from sklearn.utils import resample

# %%
n = df.status.value_counts()[1]

df_majority = df[df.status==0]
df_minority = df[df.status==1]

df_majority_upsampled = resample(df_majority,replace=True,n_samples = n,random_state=42)

df = pd.concat([df_minority,df_majority_upsampled])
df.status.value_counts()
# Out:
# 1    147
# 0    147
# Name: status, dtype: int64

# %%
y = df["status"]

# %%
cols=['MDVP:RAP','Jitter:DDP','MDVP:Fhi(Hz)','status']

# %%
x=df.drop(cols,axis=1)

# %%
x
# Out:
#      MDVP:Fo(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:PPQ  \
# 0        119.992        74.997         0.00784          0.000070   0.00554
# 1        122.400       113.819         0.00968          0.000080   0.00696
# 2        116.682       111.555         0.01050          0.000090   0.00781
# 3        116.676       111.366         0.00997          0.000090   0.00698
# 4        116.014       110.655         0.01284          0.000110   0.00908
# ..           ...           ...             ...               ...       ...
# 44       243.439       232.435         0.00210          0.000009   0.00137
# 50       124.445       117.495         0.00431          0.000030   0.00167
# 50       124.445       117.495         0.00431          0.000030   0.00167
# 166      237.323       229.256         0.00303          0.000010   0.00159
# 188      114.563        86.647         0.00327          0.000030   0.00184
#
# ...

# %%
x.dtypes
# Out:
# MDVP:Fo(Hz)         float64
# MDVP:Flo(Hz)        float64
# MDVP:Jitter(%)      float64
# MDVP:Jitter(Abs)    float64
# MDVP:PPQ            float64
# MDVP:Shimmer        float64
# MDVP:Shimmer(dB)    float64
# Shimmer:APQ3        float64
# Shimmer:APQ5        float64
# MDVP:APQ            float64
# Shimmer:DDA         float64
# NHR                 float64
# HNR                 float64
# RPDE                float64
# DFA                 float64
# spread1             float64
# spread2             float64
# D2                  float64
# PPE                 float64
# dtype: object

# %%
MDVP:Fo(Hz) - Average vocal fundamental frequency
MDVP:Fhi(Hz) - Maximum vocal fundamental frequency
MDVP:Flo(Hz) - Minimum vocal fundamental frequency
MDVP:Jitter(%),MDVP:Jitter(Abs),MDVP:RAP,MDVP:PPQ,Jitter:DDP - Several
measures of variation in fundamental frequency
MDVP:Shimmer,MDVP:Shimmer(dB),Shimmer:APQ3,Shimmer:APQ5,MDVP:APQ,Shimmer:DDA - Several measures of variation in amplitude
NHR,HNR - Two measures of ratio of noise to tonal components in the voice
status - Health status of the subject (one) - Parkinson's, (zero) - healthy
RPDE,D2 - Two nonlinear dynamical complexity measures
DFA - Signal fractal scaling exponent
spread1,spread2,PPE - Three nonlinear measures of fundamental frequency variation

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 44     0
# 50     0
# 50     0
# 166    0
# 188    0
# Name: status, Length: 294, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, X_test, y_train, y_test =train_test_split(x, y, test_size=0.3)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(random_state=0)

# %%
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
print(rfc.score(x_train,y_train))
# Out:
# 1.0

# %%
from sklearn.metrics import accuracy_score
y_pred = rfc.predict(X_test )
accuracy_score(y_pred,y_test)
# Out:
# 0.9775280898876404

# %%
import pickle

pickle.dump(rfc,open('fraud.pkl','wb'))
price = pickle.load(open('fraud.pkl','rb'))

# %%
x
# Out:
#      MDVP:Fo(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  MDVP:Jitter(Abs)  MDVP:PPQ  \
# 0        119.992        74.997         0.00784          0.000070   0.00554
# 1        122.400       113.819         0.00968          0.000080   0.00696
# 2        116.682       111.555         0.01050          0.000090   0.00781
# 3        116.676       111.366         0.00997          0.000090   0.00698
# 4        116.014       110.655         0.01284          0.000110   0.00908
# ..           ...           ...             ...               ...       ...
# 44       243.439       232.435         0.00210          0.000009   0.00137
# 50       124.445       117.495         0.00431          0.000030   0.00167
# 50       124.445       117.495         0.00431          0.000030   0.00167
# 166      237.323       229.256         0.00303          0.000010   0.00159
# 188      114.563        86.647         0.00327          0.000030   0.00184
#
# ...

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 44     0
# 50     0
# 50     0
# 166    0
# 188    0
# Name: status, Length: 294, dtype: int64

# %%
import sklearn.metrics

# %%
print(sklearn.metrics.classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        44
#            1       1.00      0.93      0.97        45
#
#     accuracy                           0.97        89
#    macro avg       0.97      0.97      0.97        89
# weighted avg       0.97      0.97      0.97        89

# %%
y_pred = rfc.predict(X_test )
y_true=y_test


from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm
# Out:
# array([[44,  0],
#        [ 3, 42]], dtype=int64)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

f, ax=plt.subplots(figsize=(5,5))
sns.heatmap(cm,annot=True,linewidths=0.5,linecolor="red",fmt=".0f",ax=ax)
plt.xlabel("y_pred")
plt.ylabel("y_true")
plt.show()
